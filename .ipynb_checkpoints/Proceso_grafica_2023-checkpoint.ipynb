# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("vic_año-hab.csv")
df
# Out:
#             comunidad_autonoma  n_victimas_mortales
# 0                    Andalucía                 17.0
# 1                       Aragón                  1.0
# 2                     Canarias                  3.0
# 3              Castilla y León                  3.0
# 4           Castilla-La Mancha                  2.0
# 5                     Cataluña                 10.0
# 6   Comunidad Foral de Navarra                  1.0
# 7          Comunidad de Madrid                  7.0
# 8         Comunitat Valenciana                  6.0
# 9                      Galicia                  3.0
# 10                    La Rioja                  1.0
# 11                  País Vasco                  2.0
# 12            Región de Murcia                  1.0

# %%
df=df.sort_values(by="n_victimas_mortales",ascending=False)

# %%
plt.barh(df["comunidad_autonoma"], df["n_victimas_mortales"],color="blue", alpha=0.3)

plt.xticks(rotation=70)
plt.xlabel("Nº Muertes 2023")
plt.title("Muertes por violencia de genero por cada C. Autonoma")

plt.show()

# %%
df.drop("Unnamed: 0", axis = 1, inplace= True)

# %%
df = df.reset_index()
df.drop(["index"], axis=1, inplace=True)
