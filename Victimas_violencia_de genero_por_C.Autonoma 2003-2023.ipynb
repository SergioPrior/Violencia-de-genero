# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("vic_cAut.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 comunidad_autonoma  n_victimas_mortales
# 0           0          Andalucía                  258
# 1           1             Aragón                   33
# 2           2           Canarias                   82
# 3           3          Cantabria                   11
# 4           4    Castilla y León                   62

# %%
plt.barh(df["comunidad_autonoma"], df["n_victimas_mortales"],color="blue")
plt.xticks(rotation=70)
plt.xlabel("Nº Victimas 2003-2023.")
plt.ylabel("Comunidad Autonoma.")
plt.title("Victimas Violencia de genero por C.Autonoma.")

plt.show()
