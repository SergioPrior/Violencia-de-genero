# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("vic_c_20años.csv")
df2 = pd.read_excel("2853.xlsx")
años= pd.read_csv("años.csv")

# %%
df=df.sort_values(by="n_victimas_mortales",ascending=False)
df.n_victimas_mortales = df.n_victimas_mortales.astype(int)

# %%
plt.barh(df["comunidad_autonoma"], df["n_victimas_mortales"],color="red", alpha=0.6)

for index, value in enumerate(df["n_victimas_mortales"]):
    plt.text(value, index, f'{value}', fontsize=8)

plt.xticks(rotation=70)
plt.xlabel("Nº Muertes 2003-2023")
plt.title("Muertes por violencia de genero por C. Autonoma")

plt.show()

# %%
df.drop("Unnamed: 0", axis = 1, inplace= True)

# %%
df = df.reset_index()
df.drop(["index"], axis=1, inplace=True)
df
# Out:
#             comunidad_autonoma  n_victimas_mortales
# 0                    Andalucía                  258
# 1                     Cataluña                  198
# 2         Comunitat Valenciana                  153
# 3          Comunidad de Madrid                  131
# 4                     Canarias                   82
# 5                      Galicia                   67
# 6              Castilla y León                   62
# 7           Castilla-La Mancha                   57
# 8                Illes Balears                   41
# 9                   País Vasco                   41
# 10            Región de Murcia                   35
# 11                      Aragón                   33
# 12      Principado de Asturias                   28
# 13  Comunidad Foral de Navarra                   15
# 14                 Extremadura                   12
# 15                   Cantabria                   11
# 16                    La Rioja                    8
# 17                     Melilla                    5
# 18                       Ceuta                    3

# %%
df2=df2.dropna()

# %%
df2=df2.drop(columns="COMUNIDAD AUTONOMA")

# %%
df_p=df.join(df2)

# %%
df_p.rename(columns={"n_victimas_mortales":"n_victimas_mortales x20 años","TOTAL MEDIA":"total_pob x20 años"}, inplace = True)

# %%
n_victimas = df_p["n_victimas_mortales x20 años"] / df_p["total_pob x20 años"] * 1000000

# %%
data = pd.DataFrame(n_victimas)

# %%
df_p = df_p.join(data)

# %%
df_p.rename(columns={0:"victimas x M habitantes"}, inplace=True)

# %%
df_p["victimas x M habitantes"]=df_p["victimas x M habitantes"].round(2)

# %%
df_p.sort_values(by="victimas x M habitantes", ascending=True, inplace=True)
df_p
# Out:
#             comunidad_autonoma  n_victimas_mortales x20 años  \
# 14                 Extremadura                            12
# 9                   País Vasco                            41
# 15                   Cantabria                            11
# 3          Comunidad de Madrid                           131
# 13  Comunidad Foral de Navarra                            15
# 5                      Galicia                            67
# 10            Región de Murcia                            35
# 6              Castilla y León                            62
# 11                      Aragón                            33
# 16                    La Rioja                             8
# 12      Principado de Asturias                            28
# 1                     Cataluña                           198
# 7           Castilla-La Mancha                            57
# 2         Comunitat Valenciana                           153
# 0                    Andalucía                           258
# 18                       Ceuta                             3
# 8                Illes Balears                            41
# 4                     Canarias                            82
# 17                     Melilla                             5
#
#     total_pob x20 años  victimas x M habitantes
# 14             1033135                    11.62
# 9              2065409                    19.85
# 15              550762                    19.97
# 3              6040853                    21.69
# 13              598639                    25.06
# 5              2611586                    25.65
# 10             1364234                    25.66
# 6              2363778                    26.23
# 11             1246472                    26.47
# 16              298350                    26.81
# 12             1006324                    27.82
# 1              7039924                    28.13
# 7              1919763                    29.69
# 2              4698240                    32.57
# 0              7833727                    32.93
# 18               77044                    38.94
# 8              1029493                    39.83
# 4              1975394                    41.51
# 17               74531                    67.09

# %%
años
# Out:
#        año
# 0     2012
# 1     2006
# 2     2009
# 3     2023
# 4     2012
# ...    ...
# 1235  2003
# 1236  2003
# 1237  2003
# 1238  2003
# 1239  2004
#
# [1240 rows x 1 columns]

# %%
df_p.pivot_table(index="n_victimas_mortales x20 años",
                columns="",
                values=)

# %%
plt.barh(df_p["comunidad_autonoma"], df_p["victimas x M habitantes"],color="red", alpha=0.6)

for index, value in enumerate(df_p["victimas x M habitantes"]):
    plt.text(value, index, f'{value}', fontsize=8)

plt.xticks(rotation=0)
plt.xlabel("Nº Muertes")
plt.title("Muertes victimas por cada M de habitantes")

plt.show()

# %%
desempleo = pd.read_csv("desempleo.csv")

# %%
desempleo
# Out:
#                      CCAA  tasa de desempleo %
# 0             País Vasco                   6.3
# 1              Cantabria                   7.5
# 2                 Aragón                   7.9
# 3               Cataluña                   9.0
# 4                Galicia                   9.2
# 5                Navarra                   9.3
# 6        Castilla y León                   9.5
# 7               La Rioja                   9.5
# 8    Comunidad de Madrid                   9.7
# 9       Región de Murcia                  11.3
# 10        Islas Baleares                  11.4
# 11              Asturias                  11.8
# 12    Castilla-La Mancha                  12.5
# 13  Comunidad Valenciana                  12.7
# 14              Canarias                  16.2
# 15           Extremadura                  16.3
# 16             Andalucía                  17.6
# 17               Melilla                  27.4
# 18                 Ceuta                  28.4

# %%
df_p = df_p.reset_index()

df_p.drop(columns="index", inplace = True)

# %%
df_p["comunidad_autonoma"]=df_p["comunidad_autonoma"].replace("Comunidad Foral de Navarra","Navarra")
df_p["comunidad_autonoma"]=df_p["comunidad_autonoma"].replace("Illes Balears","Islas Baleares")
df_p["comunidad_autonoma"]=df_p["comunidad_autonoma"].replace("Principado de Asturias","Asturias")
df_p["comunidad_autonoma"]=df_p["comunidad_autonoma"].replace("Comunitat Valenciana","Comunidad Valenciana")
df_p.rename(columns={"comunidad_autonoma":"CCAA"}, inplace=True)

# %%
df_p
# Out:
#                     CCAA  n_victimas_mortales x20 años  total_pob x20 años  \
# 0            Extremadura                            12             1033135
# 1             País Vasco                            41             2065409
# 2              Cantabria                            11              550762
# 3    Comunidad de Madrid                           131             6040853
# 4                Navarra                            15              598639
# 5                Galicia                            67             2611586
# 6       Región de Murcia                            35             1364234
# 7        Castilla y León                            62             2363778
# 8                 Aragón                            33             1246472
# 9               La Rioja                             8              298350
# 10              Asturias                            28             1006324
# 11              Cataluña                           198             7039924
# 12    Castilla-La Mancha                            57             1919763
# 13  Comunidad Valenciana                           153             4698240
# 14             Andalucía                           258             7833727
# 15                 Ceuta                             3               77044
# 16        Islas Baleares                            41             1029493
# 17              Canarias                            82             1975394
# 18               Melilla                             5               74531
#
#     victimas x M habitantes
# 0                     11.62
# 1                     19.85
# 2                     19.97
# 3                     21.69
# 4                     25.06
# 5                     25.65
# 6                     25.66
# 7                     26.23
# 8                     26.47
# 9                     26.81
# 10                    27.82
# 11                    28.13
# 12                    29.69
# 13                    32.57
# 14                    32.93
# 15                    38.94
# 16                    39.83
# 17                    41.51
# 18                    67.09

# %%
desempleo=desempleo.sort_values(by="CCAA").reset_index(drop=True)

# %%
df_p = df_p.sort_values(by='CCAA').reset_index(drop=True)

# %%
df_p.CCAA= df_p.CCAA.str.lower()
desempleo.CCAA=desempleo.CCAA.str.lower()

# %%
df_fusion = df_p.merge(desempleo, on= "CCAA", how='left')

# %%
df_fusion['tasa de desempleo %'] = desempleo['tasa de desempleo %']

# %%
type(df_fusion)
# Out:
# pandas.core.frame.DataFrame

# %%
df_fusion.sort_values(by="victimas x M habitantes", ascending=False)
# Out:
#                     CCAA  n_victimas_mortales x20 años  total_pob x20 años  \
# 15               melilla                             5               74531
# 3               canarias                            82             1975394
# 13        islas baleares                            41             1029493
# 8                  ceuta                             3               77044
# 0              andalucía                           258             7833727
# 9   comunidad valenciana                           153             4698240
# 6     castilla-la mancha                            57             1919763
# 7               cataluña                           198             7039924
# 2               asturias                            28             1006324
# 14              la rioja                             8              298350
# 1                 aragón                            33             1246472
# 5        castilla y león                            62             2363778
# 18      región de murcia                            35             1364234
# 12               galicia                            67             2611586
# 16               navarra                            15              598639
# 10   comunidad de madrid                           131             6040853
# 4              cantabria                            11              550762
# 17            país vasco                            41             2065409
# 11           extremadura                            12             1033135
#
#     victimas x M habitantes  tasa de desempleo %
# 15                    67.09                 27.4
# 3                     41.51                 16.2
# 13                    39.83                 11.4
# 8                     38.94                 28.4
# 0                     32.93                 17.6
# 9                     32.57                 12.7
# 6                     29.69                 12.5
# 7                     28.13                  9.0
# 2                     27.82                 11.8
# 14                    26.81                  9.5
# 1                     26.47                  7.9
# 5                     26.23                  9.5
# 18                    25.66                 11.3
# 12                    25.65                  9.2
# 16                    25.06                  9.3
# 10                    21.69                  9.7
# 4                     19.97                  7.5
# 17                    19.85                  6.3
# 11                    11.62                 16.3

# %%
df_comp=df_fusion.groupby(["CCAA","tasa de desempleo %"])["victimas x M habitantes"].sum().reset_index()

# %%
dgtmp=df_comp.drop(columns="tasa de desempleo %")
dgtmp.sort_values(by="victimas x M habitantes", ascending=False)
# Out:
#                     CCAA  victimas x M habitantes
# 15               melilla                    67.09
# 3               canarias                    41.51
# 13        islas baleares                    39.83
# 8                  ceuta                    38.94
# 0              andalucía                    32.93
# 10  comunidad valenciana                    32.57
# 6     castilla-la mancha                    29.69
# 7               cataluña                    28.13
# 2               asturias                    27.82
# 14              la rioja                    26.81
# 1                 aragón                    26.47
# 5        castilla y león                    26.23
# 18      región de murcia                    25.66
# 12               galicia                    25.65
# 16               navarra                    25.06
# 9    comunidad de madrid                    21.69
# 4              cantabria                    19.97
# 17            país vasco                    19.85
# 11           extremadura                    11.62

# %%
df_comp.sort_values(by="tasa de desempleo %", ascending=False)
# Out:
#                     CCAA  tasa de desempleo %  victimas x M habitantes
# 8                  ceuta                 28.4                    38.94
# 15               melilla                 27.4                    67.09
# 0              andalucía                 17.6                    32.93
# 11           extremadura                 16.3                    11.62
# 3               canarias                 16.2                    41.51
# 10  comunidad valenciana                 12.7                    32.57
# 6     castilla-la mancha                 12.5                    29.69
# 2               asturias                 11.8                    27.82
# 13        islas baleares                 11.4                    39.83
# 18      región de murcia                 11.3                    25.66
# 9    comunidad de madrid                  9.7                    21.69
# 5        castilla y león                  9.5                    26.23
# 14              la rioja                  9.5                    26.81
# 16               navarra                  9.3                    25.06
# 12               galicia                  9.2                    25.65
# 7               cataluña                  9.0                    28.13
# 1                 aragón                  7.9                    26.47
# 4              cantabria                  7.5                    19.97
# 17            país vasco                  6.3                    19.85
